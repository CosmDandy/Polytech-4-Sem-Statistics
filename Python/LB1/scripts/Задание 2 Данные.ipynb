     5, 3, 3, 0, 2, 4, 2, 4, 3, 2, 6, 0, 2, 4, 3, 2, 3, 2, 0, 2, 5, 3, 3, 4, 3, 1, 4, 5, 2, 4, 2, 4, 3, 3, 3, 2, 0, 6,
     2, 4, 0, 2, 4, 3, 2, 4, 3, 2, 5, 0, 2, 4, 3, 2, 3, 2, 1, 2, 3, 2, 2, 6, 5, 6, 3, 4, 3, 1, 4, 5, 2, 4, 2, 4, 3, 3,
     6, 4, 3, 4, 3, 1, 5, 3, 3, 2, 0, 6, 1, 6, 2, 2, 3, 4, 3, 2, 4, 2, 4, 3, 2, 3, 4, 4, 3, 1, 4, 5, 2, 5, 0, 2, 5, 3,
     3, 1, 2, 3, 2, 2, 3, 4, 6, 4, 4, 3, 1, 4, 5, 2, 5, 0, 2, 4, 3, 2, 6, 2]
len(x)
# Out:
# 1050

# %%
import numpy as np

data = []
for i in range(70):
    data.append(x[i * 10:(i + 15) * 10])
data
# Out:
# [[2,
#   4,
#   2,
#   4,
#   3,
#   3,
#   3,
#   2,
#   0,
#   6,
#   1,
#   2,
#   3,
#   2,
#   2,
#   1,
#   3,
#   3,
#   3,
#   2,
#   0,
#   6,
#   0,
#   2,
#   4,
#   3,
#   2,
#   1,
#   6,
#   2,
#   2,
#   1,
#   2,
#   3,
#   2,
#   2,
#   4,
#   3,
#   1,
#   4,
#   5,
#   3,
#   4,
#   3,
#   1,
#   0,
#   2,
#   5,
#   3,
#   3,
#   1,
#   6,
#   2,
#   4,
#   5,
#   2,
#   4,
#   2,
#   4,
#   3,
#   4,
#   3,
#   1,
#   4,
#   5,
#   3,
#   0,
#   2,
#   4,
#   3,
#   2,
#   3,
#   4,
#   3,
#   1,
#   2,
#   3,
#   4,
#   0,
#   2,
#   5,
#   3,
#   3,
#   3,
#   3,
#   2,
#   0,
#   6,
#   2,
#   3,
#   1,
#   5,
#   2,
#   4,
#   2,
#   4,
#   3,
#   1,
#   2,
#   3,
#   2,
#   2,
#   2,
#   3,
#   4,
#   1,
#   6,
#   2,
#   3,
#   3,
#   2,
#   0,
#   6,
#   2,
#   5,
#   0,
#   2,
#   4,
#   3,
#   2,
#   6,
#   0,
#   2,
#   5,
#   3,
#   3,
#   3,
#   5,
#   4,
#   3,
#   1,
#   4,
#   5,
#   4,
#   3,
#   2,
#   1,
#   2,
#   3,
#   2,
#   2,
#   0,
# ...

# %%
import json

data_list = []
# Добавляем новые значения в каждый объект данных
for i in range(len(data)):
    obj = {
        "Вариант": i + 1,
        "Данные": data[i]
    }
    data_list.append(obj)

# Открываем JSON файл для записи и сохраняем изменения
with open('Данные к заданию №2.json', 'w', encoding='utf-8') as file:
    json.dump(data_list, file, indent=4, ensure_ascii=False)
